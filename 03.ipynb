# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
# Đường dẫn ảnh
my_path = 'C:/Users/HP/image/2.jpg'

# %%
# Đọc ảnh 
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (183, 275)

# %%
# Thay đổi kích thước
new_size = (500,500)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=33x50>
